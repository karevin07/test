# %% [markdown]
# # 104API爬蟲

# %%
import requests
import json
import re
import csv
from bs4 import BeautifulSoup
import time

# 視覺化
import matplotlib.pyplot as plt
import pandas as pd # 引用套件並縮寫為 pd  

from pandas import Series, DataFrame 

job_url = 'http://www.104.com.tw/i/apis/jobsearch.cfm?kws={}&kwop=3&fmt=8&cols=JOB,JOB_ADDR_NO_DESCRIPT,DESCRIPTION,JOBSKILL_ALL_DESC,PCSKILL_ALL_DESC,APPEAR_DATE,NAME'
jobs = []

# %%
from sqlalchemy import create_engine
#create_engine("資料庫類型+資料庫驅動://資料庫用戶名: 資料庫密碼@IP地址:PORT號/資料庫名"，其他参数)
the_connect = create_engine('mysql+pymysql://root:754612@127.0.0.1:3306/104JOB?charset=utf8')

# %%
import pymysql
from sqlalchemy import create_engine
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password='754612', use_unicode=True, charset='utf8')
cur = conn.cursor()

# %%
cur.execute('CREATE DATABASE 104JOB ')
cur.execute('USE 104JOB')
conn.commit()

# %%
def get_list_page(jobname,number):
    for page in range(1,number):
        url = job_url.format(jobname)
        resp = requests.get(url + '&page=' + str(number))
        job_data = resp.json()['data']
        jobs.extend(job_data)                               
        time.sleep(1.5)

# %%
#總共幾頁列表
def get_totalpage(jobname):
    url = job_url.format(jobname)
    total = int(re.findall('"TOTALPAGE":"(\d+)"',requests.get(url).text)[0])
    return total

# %%
get_totalpage('軟體工程師')
# Out:
# 3667

# %%
get_list_page('軟體工程師',50)

# %%
joblist ={ }
joblist['TITLE'] = []
joblist['COMPANY'] = []
joblist['AREA'] = []
joblist['SKILL'] = []
joblist['DATE'] = []

# %%
cur.execute("""CREATE TABLE TEST (
TITLE VARCHAR(500),
COMPANY VARCHAR(500),
AREA VARCHAR(500),
SKILL VARCHAR(500),
DATE VARCHAR(500)
)""")
# Out:
# 0

# %%
for row in jobs:
    if 'JOBSKILL_ALL_DESC' not in row:
        row['JOBSKILL_ALL_DESC'] =''
    if 'PCSKILL_ALL_DESC' not in row:
        row['PCSKILL_ALL_DESC'] = ''
for row in jobs:        
        joblist['TITLE'].append(row['JOB'])
        joblist['COMPANY'].append(row['NAME'])
        joblist['AREA'].append(row['JOB_ADDR_NO_DESCRIPT'])
        joblist['SKILL'].append(row['PCSKILL_ALL_DESC'])
        joblist['DATE'].append(row['APPEAR_DATE'])

# %%
jobdf =DataFrame(joblist)

# %%
jobdf
# Out:
#        AREA      COMPANY      DATE  \
# 0    台北市內湖區     聖森股份有限公司  20180131
# 1    台北市信義區     聖森股份有限公司  20180131
# 2    台北市內湖區     聖森股份有限公司  20180131
# 3    台北市信義區     聖森股份有限公司  20180131
# 4    台北市大安區     聖森股份有限公司  20180131
# 5    台北市信義區     聖森股份有限公司  20180131
# 6    台北市大安區     聖森股份有限公司  20180131
# 7    高雄市左營區     聖森股份有限公司  20180131
# 8    台北市大安區     聖森股份有限公司  20180131
# 9    彰化縣線西鄉  新力美科技股份有限公司  20180131
# 10   台北市大安區   中華元田會計師事務所  20180131
# 11   台北市信義區   科倫數碼股份有限公司  20180131
# 12   台北市信義區   科倫數碼股份有限公司  20180131
# 13   桃園市中壢區        簾藝窗簾行  20180131
# 14   新北市中和區     恒通股份有限公司  20180131
# 15   新北市中和區     恒通股份有限公司  20180131
# 16   新北市中和區     恒通股份有限公司  20180131
# 17   新北市中和區     恒通股份有限公司  20180131
# 18   新北市中和區     恒通股份有限公司  20180131
# 19   新北市中和區     恒通股份有限公司  20180131
# 20   台北市內湖區     聖森股份有限公司  20180131
# 21   台北市信義區     聖森股份有限公司  20180131
# 22   台北市內湖區     聖森股份有限公司  20180131
# 23   台北市信義區     聖森股份有限公司  20180131
# 24   台北市大安區     聖森股份有限公司  20180131
# ...

# %%
jobdf.to_sql("TEST", the_connect,if_exists='append',index=False)
